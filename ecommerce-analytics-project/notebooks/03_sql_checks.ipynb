# %%
import sqlite3
import pandas as pd

db_path = "/home/zhgx/Portfolio_Adrian_Paneda/ecommerce-analytics-project/sql/ecommerce.db"
conn = sqlite3.connect(db_path)

print("Conected correctly to SQLite")
# Out:
# Conected correctly to SQLite

# %%
pd.read_sql("""
SELECT name 
FROM sqlite_master 
WHERE type='table';
""", conn)
# Out:
#          name
# 0  clean_data

# %%
pd.read_sql("PRAGMA table_info(clean_data);", conn)
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0     event_time     TEXT        0       None   0
# 1    1     event_type     TEXT        0       None   0
# 2    2     product_id  INTEGER        0       None   0
# 3    3    category_id  INTEGER        0       None   0
# 4    4  category_code     TEXT        0       None   0
# 5    5          brand     TEXT        0       None   0
# 6    6          price     REAL        0       None   0
# 7    7        user_id  INTEGER        0       None   0
# 8    8   user_session     TEXT        0       None   0

# %%
pd.read_sql("SELECT COUNT(*) AS n_rows FROM clean_data;", conn)
# Out:
#    n_rows
# 0   99869

# %%
pd.read_sql("SELECT * FROM clean_data LIMIT 5;", conn)
# Out:
#                   event_time event_type  product_id          category_id  \
# 0  2019-10-02 02:49:24+00:00       view     1500208  2053013552955916539
# 1  2019-10-03 09:22:26+00:00       view    26402505  2053013563651392361
# 2  2019-10-02 18:06:36+00:00       view     3801361  2053013566176363511
# 3  2019-10-03 16:12:48+00:00       view    11600016  2053013554566529381
# 4  2019-10-01 06:38:24+00:00       view    17400231  2053013558727279193
#
#                    category_code     brand   price    user_id  \
# 0  computers.peripherals.printer     xerox   94.98  517567639
# 1                        unknown   unknown  950.73  515486711
# 2                appliances.iron     tefal   84.69  512990124
# 3              computers.desktop  microlab  179.12  518802500
# 4                        unknown   unknown    3.09  519078297
#
#                            user_session
# 0  69e6455e-60ba-45aa-8adf-e2f8368b38e2
# 1  530fd038-f953-4642-ae76-899927504bcc
# ...

# %%
pd.read_sql("SELECT * FROM clean_data WHERE price > 100 LIMIT 5;", conn)
# Out:
#                   event_time event_type  product_id          category_id  \
# 0  2019-10-03 09:22:26+00:00       view    26402505  2053013563651392361
# 1  2019-10-03 16:12:48+00:00       view    11600016  2053013554566529381
# 2  2019-10-02 14:42:59+00:00       view     1005105  2053013555631882655
# 3  2019-10-02 15:21:53+00:00       view     1005179  2053013555631882655
# 4  2019-10-03 16:54:45+00:00       view    31501032  2053013558031024687
#
#             category_code     brand    price    user_id  \
# 0                 unknown   unknown   950.73  515486711
# 1       computers.desktop  microlab   179.12  518802500
# 2  electronics.smartphone     apple  1415.48  513463617
# 3  electronics.smartphone   unknown   900.64  513911405
# 4                 unknown  luminarc   158.56  542401976
#
#                            user_session
# 0  530fd038-f953-4642-ae76-899927504bcc
# 1  f18c0549-4e6b-4058-a75f-50ef19ea9340
# 2  834262d7-9b4d-4726-83f5-e1014a0e8fed
# ...
